# %% [markdown]
# <a href="https://colab.research.google.com/github/jackisace/experiments/blob/main/warhammer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
urlList = ["https://wahapedia.ru/wh40k9ed/factions/adepta-sororitas/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/adeptus-custodes/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/adeptus-mechanicus/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/astra-militarum/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/grey-knights/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/imperial-knights/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/inquisition/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/officio-assassinorum/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/rogue-traders/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/sisters-of-silence/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/space-marines/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/titan-legions/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/chaos-daemons/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/chaos-knights/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/chaos-space-marines/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/death-guard/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/heretic-titan-legions/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/renegades-and-heretics/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/thousand-sons/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/craftworlds/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/drukhari/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/harlequins/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/ynnari/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/genestealer-cults/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/necrons/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/orks/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/t-au-empire/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/tyranids/datasheets.html",
            "https://wahapedia.ru/wh40k9ed/factions/unaligned/datasheets.html"]

allContent = []

for page in urlList:
  c = requests.get(page)
  c = c.content
  allContent.append(c)

# %%
soup = bs(allContent[0])
soup.findAll("p")
